# %% [markdown]
# ### Primer Design
# This notebook defines a funciton to search for the melting temperature of many pairs of duplexes by performing a binary search over results from the parallel `concentrations` application.
#
# The following code then uses that function to search for complementary primer pairs with a desired melting temperature.

# %%
# %pylab notebook
import pandas as pd
import cupyck
import nupyck
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def melting_temp(session, jobs):
    
    jobs = jobs.join(
        pd.DataFrame([
            { "sequences"        : [job.sequence_1, job.sequence_2],
              "temperature"      : 50,
              "t_hi"             : 100,
              "t_lo"             : 0,
              "x0"               : np.array([1e-6, 1e-6]),
              "max_complex_size" : 2,
              "converged"        : False
            }
            for job in jobs.itertuples()
        ])
    )
    
    in_progress = jobs
    
    while not jobs.converged.all():

        results = session.concentrations(in_progress)
        
        duplex_yield = results.apply(
            lambda row:
              row.concentrations[1,2] / row.x0[0],
            axis = 1
        )
        
        def update(job):
            
            if job.converged:
                return job

            temp, t_hi, t_lo = job[['temperature', 't_hi', 't_lo']]
            
            yld = duplex_yield.loc[job.name]
            
            if yld >= 0.51:
                job.temperature = temp + (t_hi - temp) / 2.0
                job.t_lo = temp

            elif yld <= 0.49:
                job.temperature = temp - (temp - t_lo) / 2.0
                job.t_hi = temp
            
            else:
                job.converged = True
            
            return job
              
        jobs = jobs.apply(update, axis=1)
        
        in_progress = jobs[~jobs.converged]
        print "%d / %d complete" % (len(jobs) - len(in_progress), len(jobs))

    jobs.rename(columns={"temperature": "melting_temp"}, inplace=True)
    
    return jobs[["sequence_1", "sequence_2", "melting_temp"]]

# %%
def randseq(n):
    return "".join(np.random.choice(list("ATCG"), n))

# %%
jobs = pd.DataFrame([
    { "sequence_1": seq,
      "sequence_2": nupyck.revcomp(seq)
    }
    for seq in [randseq(20) for _ in range(5000)]
])

# %%
session = cupyck.GPUSession(max_seqlen = 50)

# %%
results = melting_temp(session, jobs)
# Out:
# 0 / 5000 complete
# 86 / 5000 complete
# 97 / 5000 complete
# 201 / 5000 complete
# 394 / 5000 complete
# 758 / 5000 complete
# 1526 / 5000 complete
# 3097 / 5000 complete
# 5000 / 5000 complete

# %%
results[(69 < results.melting_temp) & (results.melting_temp < 71) ]
# Out:
#                 sequence_1            sequence_2  melting_temp
# 1     AAATTCCATAGAATTGCCTC  GAGGCAATTCTATGGAATTT     69.140625
# 17    TTCACCTGTTGTGATTTCTC  GAGAAATCACAACAGGTGAA     70.703125
# 19    CTGGGTACTCATTTTCCAAA  TTTGGAAAATGAGTACCCAG     69.140625
# 23    TAAAGAAGCTAGTTTGACCA  TGGTCAAACTAGCTTCTTTA     70.312500
# 53    CGCTTACTACCATTAGTGCC  GGCACTAATGGTAGTAAGCG     70.898438
# 62    GGGTAGTTTTCGTCTATCGT  ACGATAGACGAAAACTACCC     70.117188
# 76    AGTGTTTGCAGAACGTAAAC  GTTTACGTTCTGCAAACACT     70.507812
# 96    GCCCATAGTAAAAGGAGTTA  TAACTCCTTTTACTATGGGC     70.312500
# 106   TTAGACTAGCACTCTTCTCC  GGAGAAGAGTGCTAGTCTAA     70.898438
# 115   CATCGTAGAGACAAAACCAA  TTGGTTTTGTCTCTACGATG     70.703125
# 117   CAATTTGATTACCTTCGCAA  TTGCGAAGGTAATCAAATTG     69.921875
# 125   GGGACCTTCTTATTGAGAGA  TCTCTCAATAAGAAGGTCCC     69.921875
# 135   ACTTAAGGAATACCACCTCC  GGAGGTGGTATTCCTTAAGT     70.312500
# 136   CGCGCAATACTGTATATCAG  CTGATATACAGTATTGCGCG     69.531250
# 142   ATTTCCGTCTAACAACTTCT  AGAAGTTGTTAGACGGAAAT     70.312500
# 149   AAGACGACAATAAAATCCAC  GTGGATTTTATTGTCGTCTT     69.531250
# 155   TTGCTTTATCAACTGCTATG  CATAGCAGTTGATAAAGCAA     69.140625
# 159   TTCCTTTCATTCCTCGAAAC  GTTTCGAGGAATGAAAGGAA     70.703125
# 160   GGTACCTTGTAAGGAAAGGG  CCCTTTCCTTACAAGGTACC     69.921875
# 175   TCCTTTATACATAAAGCGGA  TCCGCTTTATGTATAAAGGA     69.531250
# 181   AACAGGTGAAGTCAAATAGT  ACTATTTGACTTCACCTGTT     70.507812
# 183   CTTTGTGTATGAGTGAGACC  GGTCTCACTCATACACAAAG     69.335938
# 188   CATGCCTACTAGTATTGTCC  GGACAATACTAGTAGGCATG     69.921875
# 203   GACTTAAGAAGTCCCAAGGT  ACCTTGGGACTTCTTAAGTC     69.921875
# 204   TGCCATGTTAAATTGGTTGG  CCAACCAATTTAACATGGCA     70.898438
# 206   TGCACTTGTAACTCAGTATG  CATACTGAGTTACAAGTGCA     69.531250
# 210   TAGGAAGCTAATTTTCGCAA  TTGCGAAAATTAGCTTCCTA     70.312500
# 214   CCCCAGTTTCAATGTAGAAG  CTTCTACATTGAAACTGGGG     69.921875
# 224   ACTTCTCTCTAAGGCAATTT  AAATTGCCTTAGAGAGAAGT     70.312500
# 233   ATAATTGCTAAAACCTGCAC  GTGCAGGTTTTAGCAATTAT     69.726562
# ...                    ...                   ...           ...
# 4642  GAGAGGTTATAATGTTCGGA  TCCGAACATTATAACCTCTC     70.703125
# 4652  CGTATATGAAGCTAGGTCTT  AAGACCTAGCTTCATATACG     69.726562
# 4682  ATTGGTTTCAATCAGGGTAC  GTACCCTGATTGAAACCAAT     70.312500
# 4699  GTGAGATGGTTACCATGACT  AGTCATGGTAACCATCTCAC     69.140625
# 4709  CCATTGCACTTATGGTTTAG  CTAAACCATAAGTGCAATGG     69.531250
# 4725  TCTTGTTTTATCGATGTCCT  AGGACATCGATAAAACAAGA     69.531250
# 4752  CTCTTAATACTGGGCTTAGT  ACTAAGCCCAGTATTAAGAG     69.140625
# 4763  CCACGATATTGTCAGAGTCT  AGACTCTGACAATATCGTGG     70.507812
# 4770  ATTTTACGAGCAATCCATGC  GCATGGATTGCTCGTAAAAT     70.703125
# 4779  CATATTATACGCTTGACTGC  GCAGTCAAGCGTATAATATG     69.335938
# 4781  ATAGAGGAGGTCTAGCATAG  CTATGCTAGACCTCCTCTAT     70.507812
# 4790  ATAAGTTAAAGCGTCCATAA  TTATGGACGCTTTAACTTAT     69.921875
# 4804  ATTTGAGATACGTCCAAGAT  ATCTTGGACGTATCTCAAAT     69.531250
# 4813  AAAAAGCATTAGAGACTGAA  TTCAGTCTCTAATGCTTTTT     69.140625
# 4823  GCTCTAACTACTGTCACTCA  TGAGTGACAGTAGTTAGAGC     69.726562
# 4824  AAGTACTAACGATCAGAAGA  TCTTCTGATCGTTAGTACTT     69.335938
# 4827  TTAGGAGGTCGACTATTAAC  GTTAATAGTCGACCTCCTAA     69.921875
# 4849  TTTCTTGACCTTATGACCAT  ATGGTCATAAGGTCAAGAAA     69.335938
# 4884  TAAAGTTTCTAATGCCCAAT  ATTGGGCATTAGAAACTTTA     69.531250
# 4901  GCACATATCTCCTTCAGGAC  GTCCTGAAGGAGATATGTGC     70.898438
# 4917  GTGGTAACGTCATTTAACGA  TCGTTAAATGACGTTACCAC     69.335938
# 4919  AAGAACTGATCCGAAGGATT  AATCCTTCGGATCAGTTCTT     69.531250
# 4921  GGCCACAACTTATACTTACC  GGTAAGTATAAGTTGTGGCC     69.531250
# 4954  AAGTGACTTCCAATATGTCG  CGACATATTGGAAGTCACTT     69.921875
# 4969  GGCCTTAATTGAACTGTATT  AATACAGTTCAATTAAGGCC     69.335938
# 4970  TACATCTCATTAACTCACGG  CCGTGAGTTAATGAGATGTA     69.335938
# 4972  TTGTCTAGTAGTTGAAGCTT  AAGCTTCAACTACTAGACAA     69.726562
# 4980  AGAGTTACCAACTGAAACCT  AGGTTTCAGTTGGTAACTCT     69.140625
# 4981  CTATTCCTCTCGATCAACTA  TAGTTGATCGAGAGGAATAG     69.531250
# 4999  CATGACGAAGGAGATCTAAC  GTTAGATCTCCTTCGTCATG     70.117188
#
# [440 rows x 3 columns]
